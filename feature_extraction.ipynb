# %% [markdown]
# # This is the first time the Model is run for 299x299 and Resnet50 For Sample Labels

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 17:36:06 2020

@author: Chandravaran K V
"""



import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_hub as hub
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input

images_D = 'F:\\IP_mini_project\\299x299_60img'
l=[]
    
print(l)

url='https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,299,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l.append(feature)
    
print(l[0])
print(l[0].shape)
# Out:
# Using TensorFlow backend.
# []
# [[201.51941    48.21388     0.5493874 ...   0.          0.
#     0.       ]]
# (1, 2048)

# %% [markdown]
# # This is the first time the Model is run for 299x500 and Resnet50 Sample Labels

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 17:36:06 2020

@author: Chandravaran K V
"""

import numpy as np
import os
import cv2
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_hub as hub
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input

images_D = 'F:\\IP_mini_project\\300x500_cut'
    

url='https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,500,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l1.append(feature)
    
print(l1[0])
print(l1[0].shape)
# Out:
# [array([[201.51941  ,  48.21388  ,   0.5493874, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[251.75635 ,   7.040915,   1.085439, ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[468.28754  ,  10.732384 ,   2.5334253, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[385.43698  ,   3.206227 ,   0.5357873, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[349.037    ,  33.823307 ,   3.8040485, ...,   0.5083394,
#           0.       ,   0.       ]], dtype=float32), array([[483.34167,   0.     ,   0.     , ...,   0.     ,   0.     ,
#           0.     ]], dtype=float32), array([[295.14105 ,   0.      ,   5.906437, ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[423.13577 ,  10.900322,   0.      , ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[166.77098 ,   9.158755,  15.408839, ...,   0.      ,   0.      ,
# ...

# %% [markdown]
# # This is the first time the Model is run for 299x299 and Resnet50 Test Images

# %%
images_D = 'F:\\IP_mini_project\\299x299_100_cut'
l2=[]
    

url='https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,299,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l2.append(feature)
    
print(l2[0])
print(l2[0].shape)
# Out:
# [array([[201.51941  ,  48.21388  ,   0.5493874, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[251.75635 ,   7.040915,   1.085439, ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[468.28754  ,  10.732384 ,   2.5334253, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[385.43698  ,   3.206227 ,   0.5357873, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[349.037    ,  33.823307 ,   3.8040485, ...,   0.5083394,
#           0.       ,   0.       ]], dtype=float32), array([[483.34167,   0.     ,   0.     , ...,   0.     ,   0.     ,
#           0.     ]], dtype=float32), array([[295.14105 ,   0.      ,   5.906437, ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[423.13577 ,  10.900322,   0.      , ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[166.77098 ,   9.158755,  15.408839, ...,   0.      ,   0.      ,
# ...

# %% [markdown]
# # This is the first time the Model is run for 299x500 and Resnet50 For Test Images

# %%
images_D = 'F:\\IP_mini_project\\299x500_100_cut'
l3=[]
    

url='https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,500,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l3.append(feature)
    
print(l3[0])
print(l3[0].shape)
# Out:
# [array([[201.51941  ,  48.21388  ,   0.5493874, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[251.75635 ,   7.040915,   1.085439, ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[468.28754  ,  10.732384 ,   2.5334253, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[385.43698  ,   3.206227 ,   0.5357873, ...,   0.       ,
#           0.       ,   0.       ]], dtype=float32), array([[349.037    ,  33.823307 ,   3.8040485, ...,   0.5083394,
#           0.       ,   0.       ]], dtype=float32), array([[483.34167,   0.     ,   0.     , ...,   0.     ,   0.     ,
#           0.     ]], dtype=float32), array([[295.14105 ,   0.      ,   5.906437, ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[423.13577 ,  10.900322,   0.      , ...,   0.      ,   0.      ,
#           0.      ]], dtype=float32), array([[166.77098 ,   9.158755,  15.408839, ...,   0.      ,   0.      ,
# ...

# %%
print(len(l))
print(len(l1))
print(len(l2))
print(len(l3))

# %% [markdown]
# # Find the Distance and then store in Excel Sheet along with Features

# %%
disfeatures=[]
for i in range(0,100):
    dis=[]
    for j in range(0,73):
        add=0
        for k in range(0,2047):
            sub = (l2[i][0][k]-l[j][0][k])**2
            add = add + sub
        add=add/2048
        dis.append(add)
    disfeatures.append(dis)
print(disfeatures)
# Out:
# [[2723.5764933913692, 57573.71070630335, 39565.411718291994, 41341.28161550644, 30367.21593301328, 170433.89715400335, 335304.36396971444, 129676.53469075683, 3927.6588319378284, 12533.586362507816, 249506.87569573193, 286595.1147245289, 81606.17559785969, 33081.559559333466, 176330.0030808129, 13360.775862275596, 6261.274266740074, 4793.340167603801, 621.0812163578918, 270737.16358145926, 45002.39736584291, 84843.0591908929, 39301.079931879474, 5472.517974497887, 59057.983781158284, 82592.93644031152, 8641.516404615271, 72186.06656804774, 35314.05673633322, 50943.816227056974, 9845.295055931152, 29031.379874199356, 177084.7526889242, 54011.390560995445, 175890.22588691718, 49453.977556485406, 34419.54452773557, 89767.29229201908, 90238.77569923064, 19023.156340531335, 47066.65771103373, 98802.50874472916, 88935.36823767258, 16276.33712530683, 70256.81421209725, 102563.51299401272, 53553.0557955192, 1790.3206877610432, 19512.606932587245, 212880.8700842708, 27817.045336878713, 30960.
# ...

# %%
import numpy as np
print(np.where(min(disfeatures[1])))
# Out:
# (array([0], dtype=int64),)

# %%
disfeatures1=[]
for i in range(0,100):
    dis=[]
    for j in range(0,80):
        add=0
        for k in range(0,2047):
            sub = (l3[i][0][k]-l1[j][0][k])**2
            add = add + sub
        add=add/2048
        dis.append(round(add,2))
    disfeatures1.append(dis)
print(disfeatures1)
# Out:
# [[1273.8, 9391.03, 4717.55, 5951.46, 734.67, 90299.16, 314322.4, 591.88, 183.9, 14535.67, 65105.11, 30592.35, 212583.84, 29778.98, 208.78, 73109.83, 8729.91, 742.93, 839.59, 441.42, 809.61, 177045.22, 26674.07, 8216.34, 2661.09, 1494.92, 10523.53, 2032.46, 21814.15, 45589.0, 462.91, 9989.96, 22311.49, 7195.49, 1500.23, 17977.85, 12880.15, 70885.19, 845.99, 35703.45, 1970.18, 9824.08, 2247.9, 84504.17, 85627.87, 2845.13, 1021.46, 36946.88, 99214.66, 813.36, 15008.67, 59465.9, 85993.75, 42438.33, 1363.84, 18567.21, 142789.18, 20802.72, 27781.67, 46957.57, 1606.63, 3406.36, 12950.36, 1148.22, 26650.36, 8815.28, 4564.55, 22482.82, 54024.49, 1618.95, 4408.02, 74998.08, 21363.61, 2450.34, 1576.79, 92386.76, 21284.23, 80395.3, 145052.38, 65552.69], [1093.32, 12978.21, 6654.18, 8141.57, 444.7, 103028.85, 338834.47, 801.76, 761.42, 18502.85, 75697.83, 37441.79, 232626.83, 37228.08, 1194.87, 84604.84, 12509.62, 713.33, 277.05, 1337.24, 275.81, 196977.5, 32916.53, 11832.76, 3067.24, 2157.2, 142
# ...

# %%
import os
with open('feature_distance1.csv', 'w') as f:
    for i in range(len(disfeatures1)):
        for j in range(len(disfeatures1[0])):
            f.write("%s,"%(disfeatures1[i][j]))
        f.write("\n")

# %%
import os
with open('feature_distance.csv', 'w') as f:
    for i in range(len(disfeatures)):
        for j in range(len(disfeatures[0])):
            f.write("%s,"%(disfeatures[i][j]))
        f.write("\n")

# %%
import os
with open('feature_299_299.csv', 'w') as f:
    for i in range(len(l)):
        for j in range(1,2048):
            f.write("%s,"%(l[i][0][j]))
        f.write("\n")

# %%
import os
with open('feature_299_500.csv', 'w') as f:
    for i in range(len(l1)):
        for j in range(1,2048):
            f.write("%s,"%(l1[i][0][j]))
        f.write("\n")

# %%
import numpy as np
import os
import cv2
images_D = 'F:\\IP_mini_project\\300x500_cut'
with open('images.csv', 'w') as f1:
    for f in os.listdir(images_D):
        f1.write("%s,"%(f))

# %% [markdown]
# # This is the first time the Model is run for 299x299 and Inception_v3 Sample Label

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 17:36:06 2020

@author: Chandravaran K V
"""

import numpy as np
import os
import cv2
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_hub as hub
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input

images_D = 'F:\\IP_mini_project\\299x299_60img'
l4=[]

url='https://tfhub.dev/google/imagenet/inception_v3/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,299,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l4.append(feature)
    
print("completed")
# Out:
# completed

# %% [markdown]
# # This is the first time the Model is run for 299x500and Inception_v3 Sample Label

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 11 17:36:06 2020

@author: Chandravaran K V
"""

import numpy as np
import os
import cv2
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_hub as hub
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input

images_D = 'F:\\IP_mini_project\\300x500_cut'
l5=[]   

url='https://tfhub.dev/google/imagenet/inception_v3/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,500,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l5.append(feature)
print("completed")
# Out:
# completed

# %% [markdown]
# # This is the first time the Model is run for 299x299 and Inception_v3 Test Images

# %%
images_D = 'F:\\IP_mini_project\\299x299_100_cut'
l6=[]

url='https://tfhub.dev/google/imagenet/inception_v3/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,299,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l6.append(feature)
print("completed")
# Out:
# completed

# %% [markdown]
# # This is the first time the Model is run for 299x500and Inception_v3 Test Images

# %%
images_D = 'F:\\IP_mini_project\\299x500_100_cut'
l7=[]
    

url='https://tfhub.dev/google/imagenet/inception_v3/feature_vector/4'

base_model = hub.KerasLayer(url,input_shape=(299,500,3))

base_model.trainable = False

model = keras.Sequential([base_model])

#model.summary()
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    feature = model.predict(img_data)
    l7.append(feature)
    
print("completed")
# Out:
# completed

# %% [markdown]
# # Finding Distance and storing along with Feature vectors

# %%
disfeatures_v3_299_299=[]
for i in range(0,100):
    dis=[]
    for j in range(0,73):
        add=0
        for k in range(0,2047):
            sub = (l6[i][0][k]-l4[j][0][k])**2
            add = add + sub
        add=add/2048
        dis.append(add)
    disfeatures_v3_299_299.append(dis)
print("completed")
# Out:
# completed

# %%
with open('feature_distance_v3_299_299.csv', 'w') as f:
    for i in range(len(disfeatures_v3_299_299)):
        for j in range(len(disfeatures_v3_299_299[0])):
            f.write("%s,"%(disfeatures_v3_299_299[i][j]))
        f.write("\n")

# %%
disfeatures_v3_299_500=[]
for i in range(0,100):
    dis=[]
    for j in range(0,80):
        add=0
        for k in range(0,2047):
            sub = (l7[i][0][k]-l5[j][0][k])**2
            add = add + sub
        add=add/2048
        dis.append(round(add,2))
    disfeatures_v3_299_500.append(dis)
print("completed")
# Out:
# completed

# %%
import os
with open('feature_distance_v3_299_500.csv', 'w') as f:
    for i in range(len(disfeatures_v3_299_500)):
        for j in range(len(disfeatures_v3_299_500[0])):
            f.write("%s,"%(disfeatures_v3_299_500[i][j]))
        f.write("\n")

# %%
import os
with open('feature_v3_299_299.csv', 'w') as f:
    for i in range(len(l4)):
        for j in range(1,2048):
            f.write("%s,"%(l4[i][0][j]))
        f.write("\n")

# %%
import os
with open('feature_v3_299_500.csv', 'w') as f:
    for i in range(len(l5)):
        for j in range(1,2048):
            f.write("%s,"%(l5[i][0][j]))
        f.write("\n")

# %%
print(len(l4))
print(len(l5))
print(len(l6))
print(len(l7))
# Out:
# 73
# 80
# 100
# 100
