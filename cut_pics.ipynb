# %%
import cv2 
import numpy as np 
import os
import matplotlib.pyplot as plt  

images_D =r"C:\Users\JANAVI N\Downloads\Images_IP_project\100sample_resized"
save_file= r"C:\Users\JANAVI N\Downloads\Images_IP_project\100sample_cut\\"

l=[]
splits=[]
b=0
for f in os.listdir(images_D):
    img = cv2.imread(os.path.join(images_D, f))
    #print(img[0][0])
    #print(len(img))
    d = img.shape
    print(d)
    h=int(d[0]/2)
    w=int(d[1]/2)
    
# write each cropped picture to your desired directory
    splits.append(img.shape[1]/2)
                   
    #print(splits)

    #write each cropped picture to your desired directory
    
    if w==1465:
        new_img = img[:,w-400:w+400]                #Images with width of dimension 1465*2 is cut to 800
        cv2.imwrite(save_file+f+"_"+".jpg", new_img)
        
    if w>300 and w<400:
        new_img = img[:,w-300:w+300]                  #Images with width of dimension in 600 and 800 range is cut to 600
        cv2.imwrite(save_file+f+"_"+str(j)+".jpg", new_img)
        
    if w==261:
        new_img = img[:,w-250:w+250]                 #Images with width of dimension is 261*2 is cut to 500
        cv2.imwrite(save_file+f+"_"+str(j)+".jpg", new_img)         
        
    
    #cv2.imwrite(save_file+f+"_"+str(j)+".jpg", new_img)
    print(f)
    #plt.imshow(new_img)
    #plt.show()

    #new_img = img[:][w][:]
    #cv2.imwrite(save_file+f+"_"+str(j)+".jpg", new_img)
# Out:
# (470, 2930, 3)
# 001_BTI30_0.jpg_.jpg
# (470, 2930, 3)
# 001_DGAML26_2.jpg_.jpg
# (470, 2930, 3)
# 001_DGAML48_0.jpg_.jpg
# (470, 2930, 3)
# 001_DGAML48_1.jpg_.jpg
# (470, 2930, 3)
# 001_DGDML155_2.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB4_0.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB4_1.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB4_2.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB5_0.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB5_1.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB5_2.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB8_0.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB8_1.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB8_2.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB9_0.jpg_.jpg
# (470, 2930, 3)
# 001_DGEFB9_1.jpg_.jpg
# (470, 2930, 3)
# 001_DGFW5_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 002_AML2_0.jpg_.jpg
# (470, 2930, 3)
# 002_DGBFB19_1.jpg_.jpg
# (470, 2930, 3)
# 002_DGBFB19_2.jpg_.jpg
# (470, 2930, 3)
# 002_DGBFB48_0.jpg_.jpg
# (470, 2930, 3)
# 002_DGBFB48_1.jpg_.jpg
# (470, 2930, 3)
# 002_DGBFB48_2.jpg_.jpg
# (470, 2930, 3)
# 002_DGBML1_0.jpg_.jpg
# (470, 2930, 3)
# 002_DGBML1_1.jpg_.jpg
# (470, 2930, 3)
# 002_DGBML1_2.jpg_.jpg
# (470, 2930, 3)
# 002_DGCML2_0.jpg_.jpg
# (470, 2930, 3)
# 002_DGCML2_1.jpg_.jpg
# (470, 2930, 3)
# 002_DGCML2_2.jpg_.jpg
# (470, 2930, 3)
# 002_DGCML34_0.jpg_.jpg
# (470, 2930, 3)
# 002_DGFB9_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 003_DGFB103 (3)_1.jpg_.jpg
# (470, 2930, 3)
# 004_BML055_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 004_DFB79_2.jpg_.jpg_.jpg
# (470, 2930, 3)
# 004_DGAFB4 (2)_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB10_0.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB10_1.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB10_2.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB18_0.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB18_1.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB18_2.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB50_0.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB50_1.jpg_.jpg
# (470, 2930, 3)
# 004_DGBFB50_2.jpg_.jpg
# (470, 2930, 3)
# 004_DGBTI2_0.jpg_.jpg
# (470, 2930, 3)
# 004_DGBTI2_1.jpg_.jpg
# (470, 2930, 3)
# 004_DGBTI2_2.jpg_.jpg
# (470, 2930, 3)
# 004_DGCML4_0.jpg_.jpg
# (470, 2930, 3)
# 005_DGFB105_2.jpg_.jpg
# (470, 2930, 3)
# 005_DGGML-55_1.jpg_.jpg
# (470, 2930, 3)
# 005_DGGML-55_2.jpg_.jpg
# (470, 2930, 3)
# 005_DGGTI-5_0.jpg_.jpg
# (470, 2930, 3)
# 005_DGGTI-5_1.jpg_.jpg
# (470, 2930, 3)
# 005_DGGTI-5_2.jpg_.jpg
# (470, 2930, 3)
# 005_DGHFW5_0.jpg_.jpg
# (470, 2930, 3)
# 005_DGHFW5_1.jpg_.jpg
# (470, 2930, 3)
# 005_DGHFW5_2.jpg_.jpg
# (470, 2930, 3)
# 005_DGHML15_0.jpg_.jpg
# (470, 2930, 3)
# 005_DGHML15_1.jpg_.jpg
# (470, 2930, 3)
# 005_DGHML15_2.jpg_.jpg
# (470, 2930, 3)
# 005_DGHML78_0.jpg_.jpg
# (470, 2930, 3)
# 007_DGBFB11_0.jpg_.jpg
# (470, 2930, 3)
# 007_DGBFB7_0.jpg_.jpg
# (470, 2930, 3)
# 007_DGBFB7_1.jpg_.jpg
# (470, 2930, 3)
# 007_DGBFB7_2.jpg_.jpg
# (470, 2930, 3)
# 007_DGBFB8_0.jpg_.jpg
# (470, 2930, 3)
# 007_DGBFB8_1.jpg_.jpg
# (470, 2930, 3)
# 007_DGBFB8_2.jpg_.jpg
# (470, 2930, 3)
# 007_DGFB137_0.jpg_.jpg
# (470, 2930, 3)
# 007_DGNFB007_0.jpg_.jpg
# (470, 2930, 3)
# 008_DGFB14_2.jpg_.jpg
# (470, 2930, 3)
# 008_DGFB8 (13)_2.jpg_.jpg
# (470, 2930, 3)
# 008_DGFB8_0.jpg_.jpg
# (470, 2930, 3)
# 008_W8_1.jpg_.jpg
# (470, 2930, 3)
# 009_DGDML1_2.jpg_.jpg
# (470, 2930, 3)
# 009_DGFB74_0.jpg_.jpg_.jpg
# (470, 2930, 3)
# 010_AML-110_2.jpg_.jpg
# (470, 2930, 3)
# 010_DGGTI10_1.jpg_.jpg
# (470, 2930, 3)
# 011_DGFB29 (2)_2.jpg_.jpg_.jpg
# (470, 2930, 3)
# 012_DGDML101_2.jpg_.jpg
# (470, 2930, 3)
# 012_DGDRB10_0.jpg_.jpg
# (470, 2930, 3)
# 014_DGAFB8_1.jpg_.jpg
# (470, 2930, 3)
# 014_DGDML24_2.jpg_.jpg
# (470, 2930, 3)
# 014_DGVML38_0.jpg_.jpg
# (470, 2930, 3)
# 015_DBRW14_0.jpg_.jpg
# (470, 2930, 3)
# 020_AML-70_1.jpg_.jpg
# (470, 2930, 3)
# 024_EBR33_3.jpg_.jpg
# (470, 2930, 3)
# 026_PFB26_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 027_AFB11_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 027_DGBFB27 (2)_2.jpg_.jpg_.jpg
# (470, 2930, 3)
# 027_DGCML28_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 027_DGGML-77_2.jpg_.jpg_.jpg
# (470, 2930, 3)
# 029_DGVFB19_0.jpg_.jpg
# (470, 2930, 3)
# 031_DGCML32_0.jpg_.jpg_.jpg
# (470, 2930, 3)
# 032_DGFB18_3.jpg_.jpg_.jpg
# (470, 2930, 3)
# 036_HMDML1CO12_1.jpg_.jpg_.jpg
# (470, 2930, 3)
# 038_EBR45_0.jpg_.jpg
# (470, 2930, 3)
# 038_EBR45_1.jpg_.jpg
# (470, 2930, 3)
# 044_EBR51_3.jpg_.jpg
# (470, 2930, 3)
# 045_EBR52_0.jpg_.jpg
